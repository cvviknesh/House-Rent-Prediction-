# %% [markdown]
# # IMPORTING NECCESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("/content/house_price_data (2).csv")
df
# Out:
#                   location  size  total_sqft  bath  price  price_per_sqft  bhk
# 0      Devarachikkanahalli     2      1250.0     2   40.0     3200.000000    2
# 1      Devarachikkanahalli     2      1200.0     2   83.0     6916.666667    2
# 2      Devarachikkanahalli     2      1170.0     2   40.0     3418.803419    2
# 3      Devarachikkanahalli     3      1425.0     2   65.0     4561.403509    3
# 4      Devarachikkanahalli     2       947.0     2   43.0     4540.654699    2
# ...                    ...   ...         ...   ...    ...             ...  ...
# 6089          Yeshwanthpur     2      1195.0     2  100.0     8368.200837    2
# 6090          Yeshwanthpur     3      1692.0     3  108.0     6382.978723    3
# 6091          Yeshwanthpur     6      2500.0     5  185.0     7400.000000    6
# 6092          Yeshwanthpur     3      1855.0     3  135.0     7277.628032    3
# 6093          Yeshwanthpur     3      1876.0     3  160.0     8528.784648    3
#
# [6094 rows x 7 columns]

# %%
# LOCATION:THE AREA WHERE THE PROPERTY IS LOCATED.
# SIZE: SIZE OF THE PROPERTY
# TOTAL_SQFT:THE TOTAL AREA OF THE PROPERTY IN SQUARE FEET.
# BATH:THE NUMBER OF BATHROOMS IN THE PROPERTY.
# PRICE: THE TOTAL PRICE OF THE PROPERTY.
# PRICE PER SQFT:THE PRICE OF THE PROPERTY PER SQFT.
# BHK:THE NUMBER OF BEDROOMS,HALL,KITCHENS(2BHK MEANS 2 BEDROOM,A HALL AND KITCHEN)

# %%
df.shape
# Out:
# (6094, 7)

# %%
df.columns
# Out:
# Index(['location', 'size', 'total_sqft', 'bath', 'price', 'price_per_sqft',
#        'bhk'],
#       dtype='object')

# %%
df.head()
# Out:
#                location  size  total_sqft  bath  price  price_per_sqft  bhk
# 0   Devarachikkanahalli     2      1250.0     2   40.0     3200.000000    2
# 1   Devarachikkanahalli     2      1200.0     2   83.0     6916.666667    2
# 2   Devarachikkanahalli     2      1170.0     2   40.0     3418.803419    2
# 3   Devarachikkanahalli     3      1425.0     2   65.0     4561.403509    3
# 4   Devarachikkanahalli     2       947.0     2   43.0     4540.654699    2

# %%
df.tail()
# Out:
#           location  size  total_sqft  bath  price  price_per_sqft  bhk
# 6089  Yeshwanthpur     2      1195.0     2  100.0     8368.200837    2
# 6090  Yeshwanthpur     3      1692.0     3  108.0     6382.978723    3
# 6091  Yeshwanthpur     6      2500.0     5  185.0     7400.000000    6
# 6092  Yeshwanthpur     3      1855.0     3  135.0     7277.628032    3
# 6093  Yeshwanthpur     3      1876.0     3  160.0     8528.784648    3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6094 entries, 0 to 6093
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        6094 non-null   object
#  1   size            6094 non-null   int64
#  2   total_sqft      6094 non-null   float64
#  3   bath            6094 non-null   int64
#  4   price           6094 non-null   float64
#  5   price_per_sqft  6094 non-null   float64
#  6   bhk             6094 non-null   int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 333.4+ KB

# %%
df.describe()
# Out:
#               size    total_sqft         bath        price  price_per_sqft  \
# count  6094.000000   6094.000000  6094.000000  6094.000000     6094.000000
# mean      2.442074   1431.400343     2.376108    89.145588     5801.798188
# std       0.826987    679.984463     0.866614    78.281817     2235.078881
# min       1.000000    300.000000     1.000000    10.000000     2090.909091
# 25%       2.000000   1085.000000     2.000000    48.000000     4420.222593
# 50%       2.000000   1246.000000     2.000000    68.000000     5444.165271
# 75%       3.000000   1629.465000     3.000000   101.000000     6596.491228
# max       9.000000  12000.000000     9.000000  2200.000000    24509.803922
#
#                bhk
# count  6094.000000
# mean      2.442074
# std       0.826987
# min       1.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.000000
# max       9.000000

# %%
df['size'].value_counts()
# Out:
# size
# 2    3267
# 3    2002
# 1     380
# 4     347
# 5      52
# 6      25
# 8       9
# 7       8
# 9       4
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# location           object
# size                int64
# total_sqft        float64
# bath                int64
# price             float64
# price_per_sqft    float64
# bhk                 int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# location          0
# size              0
# total_sqft        0
# bath              0
# price             0
# price_per_sqft    0
# bhk               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 533

# %%
df1=df.copy()

# %%
# dropping the column name size

df1.drop(columns={'size'},inplace=True)

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.shape
# Out:
# (5561, 6)

# %%
# feature engineering

cat_df1=df1.select_dtypes(include=['object'])

# %%
num_df1=df1.select_dtypes(include=['int64','float64'])

# %%
label_encoder=LabelEncoder()

# %%
cat_df1['location_name'] = label_encoder.fit_transform(cat_df1['location'])

# %%
df1=pd.concat([df1,cat_df1],axis=1)

# %%
df1.drop(columns={'location'},inplace=True)

# %%
df1
# Out:
#       total_sqft  bath   price  price_per_sqft  bhk  location_name
# 0         1250.0     2   40.00     3200.000000    2              0
# 1         1200.0     2   83.00     6916.666667    2              0
# 2         1170.0     2   40.00     3418.803419    2              0
# 3         1425.0     2   65.00     4561.403509    3              0
# 4          947.0     2   43.00     4540.654699    2              0
# ...          ...   ...     ...             ...  ...            ...
# 6088       672.0     1   36.85     5483.630952    1            239
# 6090      1692.0     3  108.00     6382.978723    3            239
# 6091      2500.0     5  185.00     7400.000000    6            239
# 6092      1855.0     3  135.00     7277.628032    3            239
# 6093      1876.0     3  160.00     8528.784648    3            239
#
# [5561 rows x 6 columns]

# %%
X=df1.drop(columns={'price'})
Y=df1['price']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# test percentage 30

# %%
print("X_TRAIN",X_train.shape)
print("X_TEST",X_test.shape)
print("Y_TRAIN",Y_train.shape)
print("Y_TEST",Y_test.shape)
# Out:
# X_TRAIN (3892, 5)
# X_TEST (1669, 5)
# Y_TRAIN (3892,)
# Y_TEST (1669,)

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.9103999887367396
